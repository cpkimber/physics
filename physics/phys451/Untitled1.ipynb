# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = arange(0, 3, 1e-5)
plt.figure(figsize=(9, 5))
plt.plot(t, 15*e**(-t/2.5))
plt.xlabel("Time (s)")
plt.ylabel("Current(A)")
plt.title("SPN 8-06 Graph")
plt.savefig("spn806.png")
